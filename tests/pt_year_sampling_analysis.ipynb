# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression as LinearRegression
# Add the src directory t\ the Python path

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# Now you can import the TimeSeriesDataset class
from src.TimeSeriesDataset import TimeSeriesDataset as TSD
from src.Template import Template
from src.utils import download_data, weighted_mean, fit_logit_to_variables
from src.mappings import value_mapping, ideology_mapping, social_complexity_mapping

# %%
use_resid = False

if use_resid:
    # Load the residuals
    dataset_filename = '..\datasets\power_transitions_with_residuals.xlsx'
else:
    dataset_filename = '..\datasets\power_transitions.xlsx'

dataset_PT = TSD(file_path=dataset_filename)
dataset_PT.raw = dataset_PT.raw.groupby('dataset').get_group('PT')
dataset_PT.scv = dataset_PT.scv.groupby('dataset').get_group('PT')
dataset_PT.scv_imputed = dataset_PT.scv_imputed.groupby('dataset').get_group('PT')

dataset_FULL = TSD(file_path=dataset_filename)
dataset = TSD(file_path=dataset_filename)
dataset.raw = dataset.raw.groupby('dataset').get_group('100y')
dataset.scv = dataset.scv.groupby('dataset').get_group('100y')
dataset.scv_imputed = dataset.scv_imputed.groupby('dataset').get_group('100y')
# Out:
# Dataset loaded from ..\datasets\power_transitions.xlsx
# Dataset loaded from ..\datasets\power_transitions.xlsx
# Dataset loaded from ..\datasets\power_transitions.xlsx

# %%
polaris_filename = "..\datasets\Polaris_data.xlsx"
religion_df = pd.read_excel(polaris_filename, sheet_name='Religion')

dataset_PT.scv['religion'] = dataset_PT.scv.PolityName.apply(lambda x: religion_df[religion_df.PolID == x].religion.values[0] if x in religion_df.PolID.values else np.nan)
dataset_PT.scv_imputed['religion'] = dataset_PT.scv_imputed.PolityName.apply(lambda x: religion_df[religion_df.PolID == x].religion.values[0] if x in religion_df.PolID.values else np.nan)
dataset_PT.scv['religion_family'] = dataset_PT.scv.PolityName.apply(lambda x: religion_df[religion_df.PolID == x].RelFam.values[0] if x in religion_df.PolID.values else np.nan)
dataset_PT.scv_imputed['religion_family'] = dataset_PT.scv_imputed.PolityName.apply(lambda x: religion_df[religion_df.PolID == x].RelFam.values[0] if x in religion_df.PolID.values else np.nan)
dataset_PT.scv['MSP'] = dataset_PT.scv.PolityName.apply(lambda x: religion_df[religion_df.PolID == x].MSP_imp.values[0] if x in religion_df.PolID.values else np.nan)
dataset_PT.scv_imputed['MSP'] = dataset_PT.scv_imputed.PolityName.apply(lambda x: religion_df[religion_df.PolID == x].MSP_imp.values[0] if x in religion_df.PolID.values else np.nan)

# %%
crisis_vars = ['overturn',
              'predecessor_assassination'
              ,'intra_elite'
              ,'military_revolt'
              ,'popular_uprising'
              ,'separatist_rebellion'
              ,'external_invasion'
              ,'external_interference'
              ]
# columns to sum into crisis variable
crisis_keep = ['overturn', 'predecessor_assassination', 'intra_elite', 'military_revolt']
PT_mapping = {'PT_types':{}}
for c,col in enumerate(crisis_vars):
    if col in crisis_keep:
        PT_mapping['PT_types'][col] = 1
    dataset_PT.scv[col] = dataset_PT.raw[col]
    dataset_PT.scv_imputed[col] = dataset_PT.scv[col]

dataset_PT.scv['Crisis'] = dataset_PT.raw.apply(lambda row: weighted_mean(row, PT_mapping, "PT_types", nan_handling='remove'), axis=1)
dataset_PT.scv_imputed['Crisis'] = dataset_PT.scv['Crisis']
dataset_PT.scv['duration'] = dataset_PT.raw['duration']
dataset_PT.scv_imputed['duration'] = dataset_PT.scv['duration']

# %%
X_cols =  ['Pop','Terr','Cap','Hierarchy','Government', 'Infrastructure', 'Information', 'Money', 'MSP', 'Miltech','Scale_1','Comp']
Xy = dataset_PT.scv_imputed[X_cols + crisis_vars]
for col in crisis_vars:
    X_cols =  ['Pop','Terr','Cap','Hierarchy','Government', 'Infrastructure', 'Information', 'Money', 'MSP', 'Miltech']

    fit_logit_to_variables(Xy, col, X_cols)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.633802
#          Iterations 5
# Removing Hierarchy with p-value 0.861111326333412
# Optimization terminated successfully.
#          Current function value: 0.633814
#          Iterations 5
# Removing Pop with p-value 0.649432990271561
# Optimization terminated successfully.
#          Current function value: 0.633896
#          Iterations 5
# Removing MSP with p-value 0.49749985316882417
# Optimization terminated successfully.
#          Current function value: 0.634749
#          Iterations 5
# Removing Cap with p-value 0.36968033560146785
# Optimization terminated successfully.
#          Current function value: 0.635066
#          Iterations 5
# Removing Money with p-value 0.35414117323568894
# Optimization terminated successfully.
#          Current function value: 0.635404
#          Iterations 5
# Removing Information with p-value 0.19419882905648578
# Optimization terminated successfully.
#          Current function value: 0.636076
#          Iterations 5
# Removing Government with p-value 0.10395843704335615
# Optimization terminated successfully.
#          Current function value: 0.637116
#          Iterations 5
# Best fit found
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               overturn   No. Observations:                 1267
# Model:                          Logit   Df Residuals:                     1263
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 19 Jun 2025   Pseudo R-squ.:                 0.03389
# Time:                        13:24:06   Log-Likelihood:                -807.23
# converged:                       True   LL-Null:                       -835.54
# Covariance Type:            nonrobust   LLR p-value:                 3.090e-12
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -3.3032      0.598     -5.526      0.000      -4.475      -2.132
# Terr               0.4727      0.088      5.375      0.000       0.300       0.645
# Infrastructure     1.4961      0.498      3.002      0.003       0.519       2.473
# Miltech           -0.2474      0.077     -3.225      0.001      -0.398      -0.097
# ==================================================================================
# const             3.283927e-08
# Terr              7.664661e-08
# Infrastructure    2.684589e-03
# Miltech           1.258797e-03
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.509015
#          Iterations 6
# Removing Hierarchy with p-value 0.5368095977591167
# Optimization terminated successfully.
#          Current function value: 0.509172
#          Iterations 6
# Removing Money with p-value 0.4010842934947013
# Optimization terminated successfully.
#          Current function value: 0.509458
#          Iterations 6
# Removing Information with p-value 0.38215701902547483
# Optimization terminated successfully.
#          Current function value: 0.509775
#          Iterations 6
# Removing Pop with p-value 0.24273599073411278
# Optimization terminated successfully.
#          Current function value: 0.510331
#          Iterations 6
# Removing Miltech with p-value 0.12235909179494149
# Optimization terminated successfully.
#          Current function value: 0.495294
#          Iterations 6
# Removing Infrastructure with p-value 0.596315399126693
# Optimization terminated successfully.
#          Current function value: 0.495361
#          Iterations 6
# Removing MSP with p-value 0.13875052483689077
# Optimization terminated successfully.
#          Current function value: 0.494324
#          Iterations 6
# Best fit found
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     predecessor_assassination   No. Observations:                 2128
# Model:                                 Logit   Df Residuals:                     2124
# Method:                                  MLE   Df Model:                            3
# Date:                       Thu, 19 Jun 2025   Pseudo R-squ.:                 0.01775
# Time:                               13:24:06   Log-Likelihood:                -1051.9
# converged:                              True   LL-Null:                       -1070.9
# Covariance Type:                   nonrobust   LLR p-value:                 2.808e-08
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.2979      0.459     -7.180      0.000      -4.198      -2.398
# Terr           0.2306      0.079      2.911      0.004       0.075       0.386
# Cap            0.3209      0.114      2.827      0.005       0.098       0.543
# Government    -1.4392      0.322     -4.471      0.000      -2.070      -0.808
# ==============================================================================
# const         6.956176e-13
# Terr          3.599476e-03
# Cap           4.698382e-03
# Government    7.774147e-06
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.669307
#          Iterations 5
# Removing Pop with p-value 0.7411106167354651
# Optimization terminated successfully.
#          Current function value: 0.669351
#          Iterations 5
# Removing Hierarchy with p-value 0.6816431242318428
# Optimization terminated successfully.
#          Current function value: 0.669420
#          Iterations 4
# Removing Infrastructure with p-value 0.6758567776625384
# Optimization terminated successfully.
#          Current function value: 0.669491
#          Iterations 4
# Removing MSP with p-value 0.43906859891887573
# Optimization terminated successfully.
#          Current function value: 0.670041
#          Iterations 4
# Removing Miltech with p-value 0.5929591151696703
# Optimization terminated successfully.
#          Current function value: 0.660745
#          Iterations 4
# Removing Cap with p-value 0.34494286626514215
# Optimization terminated successfully.
#          Current function value: 0.660957
#          Iterations 4
# Removing Government with p-value 0.1389627045655625
# Optimization terminated successfully.
#          Current function value: 0.661474
#          Iterations 4
# Removing Terr with p-value 0.11417907775420871
# Optimization terminated successfully.
#          Current function value: 0.662316
#          Iterations 4
# Best fit found
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            intra_elite   No. Observations:                 2157
# Model:                          Logit   Df Residuals:                     2154
# Method:                           MLE   Df Model:                            2
# Date:                Thu, 19 Jun 2025   Pseudo R-squ.:                0.004097
# Time:                        13:24:06   Log-Likelihood:                -1428.6
# converged:                       True   LL-Null:                       -1434.5
# Covariance Type:            nonrobust   LLR p-value:                  0.002805
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.3190      0.168     -1.901      0.057      -0.648       0.010
# Information     0.6282      0.218      2.882      0.004       0.201       1.056
# Money          -0.7868      0.251     -3.130      0.002      -1.280      -0.294
# ===============================================================================
# const          0.057257
# Information    0.003956
# Money          0.001750
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.463267
#          Iterations 7
# Removing Infrastructure with p-value 0.32694292379184664
# Optimization terminated successfully.
#          Current function value: 0.463674
#          Iterations 7
# Removing Information with p-value 0.1821767423452081
# Optimization terminated successfully.
#          Current function value: 0.464426
#          Iterations 7
# Removing Money with p-value 0.15263927556866147
# Optimization terminated successfully.
#          Current function value: 0.465246
#          Iterations 6
# Removing Government with p-value 0.14308175723328106
# Optimization terminated successfully.
#          Current function value: 0.466122
#          Iterations 6
# Best fit found
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        military_revolt   No. Observations:                 1210
# Model:                          Logit   Df Residuals:                     1203
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 19 Jun 2025   Pseudo R-squ.:                 0.07063
# Time:                        13:24:06   Log-Likelihood:                -564.01
# converged:                       True   LL-Null:                       -606.87
# Covariance Type:            nonrobust   LLR p-value:                 2.335e-16
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -6.2035      0.950     -6.531      0.000      -8.065      -4.342
# Pop            0.5396      0.217      2.488      0.013       0.115       0.965
# Terr           0.5099      0.179      2.842      0.004       0.158       0.862
# Cap           -0.5332      0.223     -2.388      0.017      -0.971      -0.096
# Hierarchy      0.3160      0.072      4.404      0.000       0.175       0.457
# MSP            1.1211      0.462      2.427      0.015       0.216       2.026
# Miltech       -0.3414      0.104     -3.285      0.001      -0.545      -0.138
# ==============================================================================
# const        6.517680e-11
# Pop          1.283240e-02
# Terr         4.488586e-03
# Cap          1.695342e-02
# Hierarchy    1.061877e-05
# MSP          1.521773e-02
# Miltech      1.020202e-03
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.243168
#          Iterations 8
# Removing Government with p-value 0.7349720395845278
# Optimization terminated successfully.
#          Current function value: 0.243215
#          Iterations 8
# Removing Miltech with p-value 0.45373452589687346
# Optimization terminated successfully.
#          Current function value: 0.259889
#          Iterations 8
# Removing Information with p-value 0.9807923819930997
# Optimization terminated successfully.
#          Current function value: 0.259889
#          Iterations 8
# Removing Hierarchy with p-value 0.8650162578785854
# Optimization terminated successfully.
#          Current function value: 0.259896
#          Iterations 8
# Removing MSP with p-value 0.31627581615583167
# Optimization terminated successfully.
#          Current function value: 0.267028
#          Iterations 8
# Removing Pop with p-value 0.07066260942843794
# Optimization terminated successfully.
#          Current function value: 0.267878
#          Iterations 8
# Best fit found
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       popular_uprising   No. Observations:                 2085
# Model:                          Logit   Df Residuals:                     2080
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 19 Jun 2025   Pseudo R-squ.:                 0.05177
# Time:                        13:24:07   Log-Likelihood:                -558.53
# converged:                       True   LL-Null:                       -589.02
# Covariance Type:            nonrobust   LLR p-value:                 1.804e-12
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -5.4597      0.777     -7.031      0.000      -6.982      -3.938
# Terr              -0.2789      0.122     -2.289      0.022      -0.518      -0.040
# Cap                0.7156      0.175      4.098      0.000       0.373       1.058
# Infrastructure    -1.5797      0.702     -2.251      0.024      -2.955      -0.204
# Money              3.0817      0.645      4.775      0.000       1.817       4.346
# ==================================================================================
# const             2.051287e-12
# Terr              2.206004e-02
# Cap               4.161680e-05
# Infrastructure    2.437853e-02
# Money             1.792636e-06
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.154894
#          Iterations 8
# Removing Money with p-value 0.9441223469186542
# Optimization terminated successfully.
#          Current function value: 0.154896
#          Iterations 8
# Removing Terr with p-value 0.7249800271915761
# Optimization terminated successfully.
#          Current function value: 0.154947
#          Iterations 8
# Removing Infrastructure with p-value 0.6835607570366389
# Optimization terminated successfully.
#          Current function value: 0.155015
#          Iterations 8
# Removing Information with p-value 0.5242926497566172
# Optimization terminated successfully.
#          Current function value: 0.155185
#          Iterations 8
# Removing MSP with p-value 0.41752588385381906
# Optimization terminated successfully.
#          Current function value: 0.158674
#          Iterations 8
# Best fit found
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     separatist_rebellion   No. Observations:                 1225
# Model:                            Logit   Df Residuals:                     1219
# Method:                             MLE   Df Model:                            5
# Date:                  Thu, 19 Jun 2025   Pseudo R-squ.:                  0.1095
# Time:                          13:24:07   Log-Likelihood:                -194.38
# converged:                         True   LL-Null:                       -218.28
# Covariance Type:              nonrobust   LLR p-value:                 3.892e-09
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.2430      1.552     -2.734      0.006      -7.285      -1.201
# Pop            1.2820      0.349      3.670      0.000       0.597       1.967
# Cap           -0.7860      0.399     -1.970      0.049      -1.568      -0.004
# Hierarchy      0.3969      0.158      2.505      0.012       0.086       0.707
# Government    -4.8125      1.030     -4.673      0.000      -6.831      -2.794
# Miltech       -0.4222      0.188     -2.247      0.025      -0.791      -0.054
# ==============================================================================
# const         0.006258
# Pop           0.000243
# Cap           0.048835
# Hierarchy     0.012233
# Government    0.000003
# Miltech       0.024637
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.383691
#          Iterations 7
# Removing MSP with p-value 0.6892888288047585
# Optimization terminated successfully.
#          Current function value: 0.382633
#          Iterations 7
# Removing Money with p-value 0.6678443682981512
# Optimization terminated successfully.
#          Current function value: 0.382706
#          Iterations 7
# Removing Cap with p-value 0.6312065648237741
# Optimization terminated successfully.
#          Current function value: 0.382798
#          Iterations 7
# Removing Terr with p-value 0.4118460647233716
# Optimization terminated successfully.
#          Current function value: 0.383067
#          Iterations 7
# Best fit found
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:      external_invasion   No. Observations:                 1260
# Model:                          Logit   Df Residuals:                     1253
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 19 Jun 2025   Pseudo R-squ.:                 0.07237
# Time:                        13:24:07   Log-Likelihood:                -482.66
# converged:                       True   LL-Null:                       -520.32
# Covariance Type:            nonrobust   LLR p-value:                 3.320e-14
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              1.2377      0.892      1.387      0.165      -0.511       2.986
# Pop               -0.5801      0.158     -3.675      0.000      -0.890      -0.271
# Hierarchy         -0.2919      0.079     -3.700      0.000      -0.447      -0.137
# Government         3.3528      0.763      4.396      0.000       1.858       4.848
# Infrastructure     3.4454      0.856      4.023      0.000       1.767       5.124
# Information       -2.4065      0.583     -4.129      0.000      -3.549      -1.264
# Miltech           -0.2632      0.106     -2.478      0.013      -0.471      -0.055
# ==================================================================================
# const             0.165400
# Pop               0.000238
# Hierarchy         0.000215
# Government        0.000011
# Infrastructure    0.000057
# Information       0.000036
# Miltech           0.013217
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.277207
#          Iterations 7
# Removing Infrastructure with p-value 0.9297354875907765
# Optimization terminated successfully.
#          Current function value: 0.277211
#          Iterations 7
# Removing MSP with p-value 0.5746766644123416
# Optimization terminated successfully.
#          Current function value: 0.276620
#          Iterations 7
# Removing Pop with p-value 0.40939235098748084
# Optimization terminated successfully.
#          Current function value: 0.276890
#          Iterations 7
# Removing Government with p-value 0.34204229803342057
# Optimization terminated successfully.
#          Current function value: 0.277266
#          Iterations 7
# Removing Hierarchy with p-value 0.34516444439709937
# Optimization terminated successfully.
#          Current function value: 0.277631
#          Iterations 7
# Removing Cap with p-value 0.2609388790883592
# Optimization terminated successfully.
#          Current function value: 0.278170
#          Iterations 7
# Removing Miltech with p-value 0.19301125944928388
# Optimization terminated successfully.
#          Current function value: 0.311249
#          Iterations 7
# Removing Terr with p-value 0.1376982061178612
# Optimization terminated successfully.
#          Current function value: 0.315609
#          Iterations 7
# Best fit found
#                              Logit Regression Results
# =================================================================================
# Dep. Variable:     external_interference   No. Observations:                 2141
# Model:                             Logit   Df Residuals:                     2138
# Method:                              MLE   Df Model:                            2
# Date:                   Thu, 19 Jun 2025   Pseudo R-squ.:                 0.01951
# Time:                           13:24:07   Log-Likelihood:                -675.72
# converged:                          True   LL-Null:                       -689.17
# Covariance Type:               nonrobust   LLR p-value:                 1.445e-06
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -1.7636      0.274     -6.431      0.000      -2.301      -1.226
# Information    -1.7524      0.342     -5.121      0.000      -2.423      -1.082
# Money           0.9131      0.438      2.086      0.037       0.055       1.771
# ===============================================================================
# const          1.270047e-10
# Information    3.046817e-07
# Money          3.700494e-02
# dtype: float64
